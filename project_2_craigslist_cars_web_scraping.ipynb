# %% [markdown]
# Project 2: Web Scraping and Regression<br/>
#
# The goal of this project is to build a linear regression model to predict some numerical value using data scraped from the world wide web.
#
# For this project, I have chosen to scrape Craigslist car postings in the SF Bay Area. The time period for my scrape is between July 10,2020 and July 12,2020. I will be collecting lots of attribute information and see how they correlate with price. Price is the target variable I am trying to predict.
#
# In this notebook, I scrape Craigslist car posting for data and save them to CSV files for later analysis.

# %% [markdown]
# ### Notebook Table of Contents
#
# 1. Imports
# 2. Scraping a Craigslist Car Post
# 3. Scraping Craigslist Results Page
# 4. Building my DataFrame
# 5. Saving the Data

# %% [markdown]
# ### 1. Imports

# %%
# import Web Scraping tools
from bs4 import BeautifulSoup
import requests

# import tools to slow down web scraping
import time
import random

# %%
# import Data Science Tools
import pandas as pd
import numpy as np
import pickle

# import csv to save data
import csv

# import datetime
from datetime import datetime

# %% [markdown]
# ### 2. Scraping a Craigslist Car Post

# %% [markdown]
# For myy first web scraping exercise, I will practice scraping one post and refine my scraping from there.

# %%
# This url may not work because the post may have been deleted.
url = "https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html"

response = requests.get(url)

# %%
response.status_code # 200 = success!
# Out:
# 200

# %%
page = response.text
page
# Out:
# '<!DOCTYPE html>\n<html class="no-js">\n<head>\n    \n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1">\n\t<meta property="og:site_name" content="craigslist">\n\t<meta name="twitter:card" content="preview">\n\t<meta property="og:title" content="2007 Toyota Camry Hybrid Sedan! - cars &amp; trucks - by owner - vehicle...">\n\t<meta name="description" content="Greetings i am selling my 2007 Toyota Camry Hybrid LE that is currently in awesome condition...">\n\t<meta property="og:description" content="Greetings i am selling my 2007 Toyota Camry Hybrid LE that is currently in awesome condition...">\n\t<meta property="og:image" content="https://images.craigslist.org/00101_jzVubKwL5kx_0CI0t2_600x450.jpg">\n\t<meta property="og:url" content="https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html">\n\t<meta property="og:type" content="article">\n\t<meta name="robots" content="noarchive,nofollow,unavailable_after: 08-Aug-20 15:54:52 PDT">\n\t<meta name="geo.position" content="37.781200;-122.461400">\n\t<meta name="geo.placename" content="San Francisco">\n\t<meta name="geo.region" content="US-CA">\n\t<title>2007 Toyota Camry Hybrid Sedan! - cars &amp; trucks - by owner - vehicle...</title>\n\t<link rel="canonical" href="https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html">\n\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9"><link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/postings.css?v=5b52bfc023861f874d707bde3cf53671">    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n</head>\n\n<body class="posting">\n<script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n        }\n        pagemode = pagemode === \'mobile\' ? \'mobile\' : \'desktop\';\n        bodyClassList.push(pagemode);\n        if (C(\'hidesearch\') === \'1\' && pagemode !== \'mobile\') {\n            bodyClassList.push(\'hide-search\');\n        }\n        var width = window.innerWidth || document.documentElement.clientWidth;\n        if (width > 1000) { bodyClassList.push(\'w1024\'); }\n        if (typeof window.sectionBase !== \'undefined\') {\n            var mode = (decodeURIComponent(C(\'cl_tocmode\') || \'\').match(new RegExp(window.sectionBase + \':([^,]+)\', \'i\')) || {})[1] || window.defaultView;\n            if (mode) {\n                bodyClassList.push(mode);\n            }\n        }\n        b.className = bodyClassList.join(\' \');\n    }());\n--></script>\n\n    <section class="page-container">\n        <div class="bglogo"></div>\n<div class="tryapp">\n    try the craigslist app &raquo;\n    <a class="appstorebtn"\n    href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">\n        Android\n    </a>\n    <a class="appstorebtn"\n    href="https://apps.apple.com/us/app/craigslist/id1336642410">\n        iOS\n    </a>\n</div>\n<header class="global-header wide">\n   <a class="header-logo" name="logoLink" href="/">CL</a>\n\n    <nav class="breadcrumbs-container">\n\n<ul class="breadcrumbs">\n        <li class="crumb area">\n            <p>\n   ...

# %%
soup = BeautifulSoup(page, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="2007 Toyota Camry Hybrid Sedan! - cars &amp; trucks - by owner - vehicle..." property="og:title"/>
# <meta content="Greetings i am selling my 2007 Toyota Camry Hybrid LE that is currently in awesome condition..." name="description"/>
# <meta content="Greetings i am selling my 2007 Toyota Camry Hybrid LE that is currently in awesome condition..." property="og:description"/>
# <meta content="https://images.craigslist.org/00101_jzVubKwL5kx_0CI0t2_600x450.jpg" property="og:image"/>
# <meta content="https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="noarchive,nofollow,unavailable_after: 08-Aug-20 15:54:52 PDT" name="robots"/>
# <meta content="37.781200;-122.461400" name="geo.position"/>
# <meta content="San Francisco" name="geo.placename"/>
# <meta content="US-CA" name="geo.region"/>
# <title>2007 Toyota Camry Hybrid Sedan! - cars &amp; trucks - by owner - vehicle...</title>
# <link href="https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html" rel="canonical"/>
# <link href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9" media="all" rel="stylesheet" type="text/css"/><link href="//www.craigslist.org/styles/postings.css?v=5b52bfc023861f874d707bde3cf53671" media="all" rel="stylesheet" type="text/css"/> <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
# </head>
# <body class="posting">
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
# <section class="page-container">
# <div class="bglogo"></div>
# <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#         Android
#     </a>
# <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#         iOS
#     </a>
# </div>
# <header class="global-header wide">
# <a class="header-logo" href="/" name="logoLink">CL</a>
# <nav class="breadcrumbs-container">
# <ul class="breadcrumbs">
# <li class="crumb area">
# <p>
# <a href="/">SF bay area</a>
# <span class="breadcrumb-arrow">&gt;</span>
# </p>
# </li>
# <li class="crumb subarea">
# <p>
# <a href="/sfc/">san francisco</a>
# <span class="breadcrumb-arrow">&gt;</span>
# </p>
# </li>
# <li class="crumb section">
# <p>
# <a href="/search/sfc/sss">for sale</a>
# <span class="breadcrumb-arrow">&gt;</span>
# </p>
# </li>
# <li class="crumb category">
# <p>
# <a href="/search/sfc/cto">cars &amp; trucks - by owner</a>
# </p>
# </li>
# </ul>
# </nav>
# <div class="userlinks">
# <ul class="user-actions">
# <li class="user post">
# <a href="https://post.craigslist.org/c/sfo">post</a>
# </li>
# <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>
# </ul>
# <ul class="user-favs-discards">
# <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number"></span><span class="fav-label"> favorites</span></a>
# </div>
# </li>
# <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="POST">
# <div class="to-banish-page">
# <input class="lastLink" name="lastLink" type="hidden" value="/sfc/cto/7156527385.html"/>
# <input class="lastTitle" name="lastTitle" type="hidden" value="2007 Toyota Camry Hybrid Sedan!"/>
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count"></span>
# <span class="discards-label"> hidden</span>
# </a>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </header>
# <header class="global-header narrow">
# <a class="header-logo" href="/">CL</a>
# <nav class="breadcrumbs-container">
# <ul class="breadcrumbs">
#
#
# san francisco            &gt;
#
# cars &amp; trucks - by owner
#
# </ul>
# </nav>
# <span class="linklike show-wide-header">...</span>
# </header>
# <section class="body">
# <header class="dateReplyBar">
# <div class="prevnext-sec">
# <div class="prevnext js-only">
# <a class="prev">◀  prev </a>
# <a class="backup" title="back to search">▲</a>
# <a class="next"> next ▶ </a>
# </div>
# </div>
# <div class="reply-button-row">
# <div class="actions-combo">
# <button class="reply-button js-only" data-href="/__SERVICE_ID__/sfo/cto/7156527385" role="button">
#       reply
#     </button>
# <div class="reply-info js-only"></div>
# <div class="fave-unfave action">
# <div class="fave" role="button" title="add to favorites">
# <div aria-hidden="true" class="icon icon-star"></div>
# <div class="action-label">favorite</div>
# </div>
# <div class="unfave" role="button" title="remove from favorites">
# <div aria-hidden="true" class="icon icon-star fav"></div>
# <div class="action-label">favorite</div>
# </div>
# </div>
# <div class="banish-unbanish action">
# <div class="banish" role="button" title="hide this posting">
# <div aria-hidden="true" class="icon icon-trash"></div>
# <div class="action-label">hide</div>
# </div>
# <div class="unbanish" role="button" title="restore this posting">
# <div aria-hidden="true" class="icon icon-trash red"></div>
# <div class="action-label">unhide</div>
# </div>
# </div>
# <div class="flag-action action">
# <div class="flag" data-flag="28" role="button" title="flag as prohibited / spam / miscategorized">
# <div aria-hidden="true" class="flagIcon">
# <span class="white-flag">⚐</span>
# <span class="black-flag">⚑</span>
# </div>
# <div class="action-label">
#                 flag
#             </div>
# </div>
# <div class="unflag">
# <div aria-hidden="true" class="flagIcon">⚑</div>
# <a class="action-label" href="https://www.craigslist.org/about/help/flags_and_community_moderation" title="thanks for flagging!">
#                 flagged
#             </a>
# </div>
# </div>
# </div>
# <p class="postinginfo reveal" id="display-date">
#                     Posted
#                     <time class="date timeago" datetime="2020-07-09T15:54:52-0700">
#                         2020-07-09 15:54
#                     </time>
# </p>
# <p class="print-information print-contact">
#                 Contact Information: <span class="print-email"></span> <span class="print-phone"></span>
# </p>
# <a href="#" id="printme">print</a>
# </div>
# </header>
# <h2 class="postingtitle">
# <span class="postingtitletext">
# <span id="titletextonly">2007 Toyota Camry Hybrid Sedan!</span> - <span class="price">$3800</span><small> (San Francisco)</small> </span>
# </h2>
# <section class="userbody">
# <figure class="iw multiimage">
# <div class="gallery">
# <span class="slider-back arrow">&lt;</span>
# <span class="slider-info">image 1 of 8</span>
# <span class="slider-forward arrow">&gt;</span>
# <div class="swipe">
# <div class="swipe-wrap">
# <div class="slide first visible" data-imgid="jzVubKwL5kx_0CI0t2" id="1_image_jzVubKwL5kx_0CI0t2">
# <img alt="1" src="https://images.craigslist.org/00101_jzVubKwL5kx_0CI0t2_600x450.jpg" title="1"/>
# </div>
# <div class="slide" data-imgid="8yT0Ej9yWLT_0CI0t2" id="2_image_8yT0Ej9yWLT_0CI0t2">
# </div>
# <div class="slide" data-imgid="ifd3lTuoTGl_0CI0t2" id="3_image_ifd3lTuoTGl_0CI0t2">
# </div>
# <div class="slide" data-imgid="mYmaF6CFDf_0CI0t2" id="4_image_mYmaF6CFDf_0CI0t2">
# </div>
# <div class="slide" data-imgid="2ikVyzVBHBk_0CI0t2" id="5_image_2ikVyzVBHBk_0CI0t2">
# </div>
# <div class="slide" data-imgid="ikhZUW830bL_0CI0t2" id="6_image_ikhZUW830bL_0CI0t2">
# </div>
# <div class="slide" data-imgid="7uIITeDc1ya_0CI0t2" id="7_image_7uIITeDc1ya_0CI0t2">
# </div>
# <div class="slide" data-imgid="ieTjtDBeK2e_0CI0t2" id="8_image_ieTjtDBeK2e_0CI0t2">
# </div>
# </div>
# </div>
# </div>
# <div id="thumbs"><a class="thumb" data-imgid="jzVubKwL5kx_0CI0t2" href="https://images.craigslist.org/00101_jzVubKwL5kx_0CI0t2_600x450.jpg" id="1_thumb_jzVubKwL5kx_0CI0t2" title="1"><img alt="1" class="selected" src="https://images.craigslist.org/00101_jzVubKwL5kx_0CI0t2_50x50c.jpg"/></a><a class="thumb" data-imgid
0CI0t2_600x450.jpg","thumb":"https://images.craigslist.org/00x0x_2ikVyzVBHBk_0CI0t2_50x50c.jpg","imgid":"3:00x0x_2ikVyzVBHBk_0CI0t2"},{"shortid":"ikhZUW830bL_0CI0t2","url":"https://images.craigslist.org/00p0p_ikhZUW830bL_0CI0t2_600x450.jpg","thumb":"https://images.craigslist.org/00p0p_ikhZUW830bL_0CI0t2_50x50c.jpg","imgid":"3:00p0p_ikhZUW830bL_0CI0t2"},{"shortid":"7uIITeDc1ya_0CI0t2","url":"https://images.craigslist.org/00K0K_7uIITeDc1ya_0CI0t2_600x450.jpg","thumb":"https://images.craigslist.org/00K0K_7uIITeDc1ya_0CI0t2_50x50c.jpg","imgid":"3:00K0K_7uIITeDc1ya_0CI0t2"},{"shortid":"ieTjtDBeK2e_0CI0t2","url":"https://images.craigslist.org/00F0F_ieTjtDBeK2e_0CI0t2_600x450.jpg","thumb":"https://images.craigslist.org/00F0F_ieTjtDBeK2e_0CI0t2_50x50c.jpg","imgid":"3:00F0F_ieTjtDBeK2e_0CI0t2"}];
# --></script>
# </figure>
# <div class="mapAndAttrs">
# <div class="mapbox">
# <div class="viewposting" data-accuracy="22" data-latitude="37.781200" data-longitude="-122.461400" id="map"></div>
# </div>
# <p class="attrgroup">
# <span><b>2007 toyota camry</b></span>
# <br/>
# </p>
# <p class="attrgroup">
# <span>fuel: <b>gas</b></span>
# <br/>
# <span>odometer: <b>132000</b></span>
# <br/>
# <span>paint color: <b>blue</b></span>
# <br/>
# <span>title status: <b>salvage</b></span>
# <br/>
# <span>transmission: <b>automatic</b></span>
# <br/>
# </p>
# </div>
# <section id="postingbody">
# <div class="print-information print-qrcode-container">
# <p class="print-qrcode-label">QR Code Link to This Post</p>
# <div class="print-qrcode" data-location="https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html"></div>
# </div>
# Greetings i am selling my 2007 Toyota Camry Hybrid LE that is currently in awesome condition <br/>
# Running and driving extremely well no mechanical issues <br/>
# Its a 2.4L 4-cylinder engine Automatic transmission super easy and fun to drive and completely amazing on gas ! <br/>
# Although it has 132K miles i’ve just went in and replaced belts hoses , water pump, spark plugs and coil packs and new hybrid battery has also been installed!<br/>
# Oil changes and tuneups on time and when needed. It was my first vehicle so very well tooken care of and serviced to its fullest potential. <br/>
# Although it is salvage due to theft never had frame or any kind of major damage <br/>
# Still a awesome car with lots of life left into it! <br/>
# just pass smog and registered. <br/>
# If interested please contact me @  <a class="show-contact" data-href="/__SERVICE_ID__/sfo/cto/7156527385" href="#" rel="nofollow" title="click to show contact info">show contact info</a>
#  Thanks for reading Stay Safe!    </section>
# <ul class="notices">
# <li>do NOT contact me with unsolicited services or offers</li>
# </ul>
# <div class="postinginfos">
# <p class="postinginfo">post id: 7156527385</p>
# <p class="postinginfo reveal">posted: <time class="date timeago" datetime="2020-07-09T15:54:52-0700">2020-07-09 15:54</time></p>
# <p class="postinginfo reveal">updated: <time class="date timeago" datetime="2020-07-09T15:54:53-0700">2020-07-09 15:54</time></p>
# <p class="postinginfo">
# <a class="email-friend" href="https://accounts.craigslist.org/eaf?postingID=7156527385&amp;token=U2FsdGVkX180MTY3OTQxNvuLXDwJgvZEhd5Fz_wXZCAqbHS6UF6fQQ6BxdJvfkzOHpM4yHfuKFY">email to friend</a>
# </p>
# <p class="postinginfo">
# <a class="bestof-link" data-flag="9" href="https://post.craigslist.org/flag?flagCode=9&amp;postingID=7156527385" title="nominate for best-of-CL">
# <span class="bestof-icon">♥ </span><span class="bestof-text">best of</span>
# </a> <sup>[<a href="https://www.craigslist.org/about/best-of-craigslist">?</a>]</sup>
# </p>
# </div>
# <div class="print-information print-pics"></div>
# </section>
# <div class="psa-box">
# <aside class="tsb">
# <ul>
# <li><a href="https://www.craigslist.org/about/safety">safety tips</a>
# </li><li><a href="https://www.craigslist.org/about/prohibited">prohibited items</a>
# </li><li><a href="https://www.craigslist.org/about/recalled_items">product recalls</a>
# </li><li><a href="https://www.craigslist.org/about/scams">avoiding scams</a>
# </li></ul>
# </aside>
# </div>
# <div class="avoid-scams">
# <aside class="tsb">
# <p>
# <a href="https://www.craigslist.org/about/scams">Avoid scams, deal locally</a>
# <em>Beware wiring (e.g. Western Union), cashier checks, money orders, shipping.</em>
# </p>
# </aside>
# </div>
# </section>
# <footer>
# <ul class="clfooter">
# <li>© 2020 <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
# <li><a href="https://www.craigslist.org/about/help/">help</a></li>
# <li><a href="https://www.craigslist.org/about/scams">safety</a></li>
# <li class="desktop"><a href="https://www.craigslist.org/about/privacy.policy">privacy</a></li>
# <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
# <li><a href="//www.craigslist.org/about/terms.of.use.en-us">terms</a><sup class="neu">new</sup></li>
# <li><a href="https://www.craigslist.org/about/">about</a></li>
# <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
# <li class="fsel mobile linklike" data-mode="regular">desktop</li>
# </ul>
# </footer>
# </section>
# <script type="text/javascript"><!--
# var countOfTotalText = "image {count} of {total}";
# var imageConfig = {"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var pID = 7156527385;
# --></script>
# <script>
#                 try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#                 </script>
# <script src="//www.craigslist.org/js/general-concat.min.js?v=9c0610119292cd3515a4e4d633412d79" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=4c56f70c4eb7294c8ffeb1d8fdcf4704" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/postings-concat.min.js?v=6ce61dfc110f086ca503caea4b7ef32c" type="text/javascript"></script>
# </body>
# </html>

# %% [markdown]
# That's great! I got a successful status code and was able to parse through the HTML with BeautifulSoup. <br/>
#
# What information do I want?
# * Year, make, and model of the car
# * Price
# * Other car attributes (odometer reading, transmission, type, size)
# * Nice to have: date of posting, post title

# %%
car_attribute_dict = {}

# %%
car_attr = soup.find_all('p', class_='attrgroup') # found the attributes
# Out:
# [<p class="attrgroup">
#  <span><b>2007 toyota camry</b></span>
#  <br/>
#  </p>,
#  <p class="attrgroup">
#  <span>fuel: <b>gas</b></span>
#  <br/>
#  <span>odometer: <b>132000</b></span>
#  <br/>
#  <span>paint color: <b>blue</b></span>
#  <br/>
#  <span>title status: <b>salvage</b></span>
#  <br/>
#  <span>transmission: <b>automatic</b></span>
#  <br/>
#  </p>]

# %%
# parsing through 2 "attrgroup" classes
attr_group_1 = soup.find('p', class_='attrgroup')
attr_group_2 = attr_group_1.find_next_sibling('p')
print(attr_group_1)
print("\n", attr_group_2)
# Out:
# <p class="attrgroup">
# <span><b>2007 toyota camry</b></span>
# <br/>
# </p>
#
#  <p class="attrgroup">
# <span>fuel: <b>gas</b></span>
# <br/>
# <span>odometer: <b>132000</b></span>
# <br/>
# <span>paint color: <b>blue</b></span>
# <br/>
# <span>title status: <b>salvage</b></span>
# <br/>
# <span>transmission: <b>automatic</b></span>
# <br/>
# </p>

# %%
# grabbing year, make, and model
attr_group_1.text.strip().split()
# Out:
# ['2007', 'toyota', 'camry']

# %%
# storing year, make, and model
car_year = attr_group_1.text.strip().split()[0]
car_make = attr_group_1.text.strip().split()[1] # this doesn't always work
car_model = ' '.join(attr_group_1.text.strip().split()[2:])
print(car_year, car_make, car_model, type(car_year), type(car_make), type(car_model))
# Out:
# 2007 toyota camry <class 'int'> <class 'str'> <class 'str'>

# %%
# populating the dictionary to be used for my DataFrame
car_attribute_dict['year'] = car_year
car_attribute_dict['make'] = car_make
car_attribute_dict['model'] = car_model

# %%
# figuring out a strategy to grab attributes from the 2nd "attrgroup" class
attr_group_2
# Out:
# <p class="attrgroup">
# <span>fuel: <b>gas</b></span>
# <br/>
# <span>odometer: <b>132000</b></span>
# <br/>
# <span>paint color: <b>blue</b></span>
# <br/>
# <span>title status: <b>salvage</b></span>
# <br/>
# <span>transmission: <b>automatic</b></span>
# <br/>
# </p>

# %%
# using the <span> tag to collect attributes
attr_group_2.find_all('span')
# Out:
# [<span>fuel: <b>gas</b></span>,
#  <span>odometer: <b>132000</b></span>,
#  <span>paint color: <b>blue</b></span>,
#  <span>title status: <b>salvage</b></span>,
#  <span>transmission: <b>automatic</b></span>]

# %%
# looping through the <span> tag to collect and add attributes to the dictionary
for attr in attr_group_2.find_all('span'):
    if ':' in attr.text: # don't grab attributes that say "cryptocurrency ok!" or something similar
        attribute = attr.text.split(':')[0].strip()
        value = attr.text.split(':')[1].strip()
        car_attribute_dict[attribute] = value
car_attribute_dict
# Out:
# {'year': 2007,
#  'make': 'toyota',
#  'model': 'camry',
#  'fuel': 'gas',
#  'odometer': '132000',
#  'paint color': 'blue',
#  'title status': 'salvage',
#  'transmission': 'automatic'}

# %%
# grabbing post title, but it doesn't look right
title_text = soup.find('span', class_='postingtitletext')
# Out:
# {'year': 2007,
#  'make': 'toyota',
#  'model': 'camry',
#  'fuel': 'gas',
#  'odometer': '132000',
#  'paint color': 'blue',
#  'title status': 'salvage',
#  'transmission': 'automatic',
#  'post_title': <span class="postingtitletext">
#  <span id="titletextonly">2007 Toyota Camry Hybrid Sedan!</span> - <span class="price">$3800</span><small> (San Francisco)</small> </span>}

# %%
# trying to use an id instead of text to get the post title
soup.find('span', id='titletextonly')
# Out:
# <span id="titletextonly">2007 Toyota Camry Hybrid Sedan!</span>

# %%
# figuring out how to grab the post title and add to my dictionary
title = soup.find('span', id='titletextonly').text
car_attribute_dict['post_title'] = title
car_attribute_dict
# Out:
# {'year': 2007,
#  'make': 'toyota',
#  'model': 'camry',
#  'fuel': 'gas',
#  'odometer': '132000',
#  'paint color': 'blue',
#  'title status': 'salvage',
#  'transmission': 'automatic',
#  'post_title': '2007 Toyota Camry Hybrid Sedan!'}

# %%
# figuring out how to grab price
soup.find('span', class_='price')
# Out:
# <span class="price">$3800</span>

# %%
price = soup.find('span', class_='price').text

# %%
# adding price to the dictionary
car_attribute_dict['price'] = price
car_attribute_dict
# Out:
# {'year': 2007,
#  'make': 'toyota',
#  'model': 'camry',
#  'fuel': 'gas',
#  'odometer': '132000',
#  'paint color': 'blue',
#  'title status': 'salvage',
#  'transmission': 'automatic',
#  'post_title': '2007 Toyota Camry Hybrid Sedan!',
#  'price': 3800}

# %%
# adding location to the dictionary
location = soup.find('small').text.strip().replace('(','').replace(')','')
car_attribute_dict['location'] = location
car_attribute_dict
# Out:
# {'year': 2007,
#  'make': 'toyota',
#  'model': 'camry',
#  'fuel': 'gas',
#  'odometer': '132000',
#  'paint color': 'blue',
#  'title status': 'salvage',
#  'transmission': 'automatic',
#  'post_title': '2007 Toyota Camry Hybrid Sedan!',
#  'price': 3800,
#  'location': 'San Francisco'}

# %%
# adding posting date to the dictionary
post_timeago = soup.find('time', class_='date timeago').text.strip()
car_attribute_dict['posting_time'] = post_timeago
car_attribute_dict
# Out:
# {'year': 2007,
#  'make': 'toyota',
#  'model': 'camry',
#  'fuel': 'gas',
#  'odometer': '132000',
#  'paint color': 'blue',
#  'title status': 'salvage',
#  'transmission': 'automatic',
#  'post_title': '2007 Toyota Camry Hybrid Sedan!',
#  'price': 3800,
#  'location': 'San Francisco',
#  'posting_time': '2020-07-09 15:54'}

# %%
posting_time = datetime.strptime(post_timeago, '%Y-%m-%d %H:%M')
posting_time
# Out:
# datetime.datetime(2020, 7, 9, 15, 54)

# %% [markdown]
# ### 3. Scraping Craigslist Results Page<br/>
# Now that I know how to scrape one Craigslist car post, how do I get links to all the Craigslist car postings?<br/>
# There are 2 things I need to scrape:<br/>
# 1. Each Craigslist car post
# 2. The main Craigslist car search results with 120 car posts per search result page

# %%
# Looking at Craigslist's main search result page
search_url = "https://sfbay.craigslist.org/search/cta"
search_response = requests.get(search_url)
search_response.status_code
# Out:
# 200

# %%
search_page = search_response.text
search_page
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>SF bay area cars &amp; trucks  - craigslist</title>\n\n    <meta name="description" content="SF bay area cars &amp; trucks  - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://sfbay.craigslist.org/search/cta">\n    <link rel="alternate" type="application/rss+xml" href="https://sfbay.craigslist.org/search/cta?format=rss" title="RSS feed for craigslist | SF bay area cars &amp; trucks  - craigslist">\n        <link rel="next" href="https://sfbay.craigslist.org/search/cta?s=120">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "1";\nvar areaRegion = "CA";\nvar catAbb = "cta";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "grid";\nvar expiredFavIDs = null;\nvar imageConfig = {"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = {"owner":"cto","dealer":"ctd","all":"cta"};\nvar searchDistance = null;\nvar sectionAbb = "sss";\nvar sectionBase = "sss";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n        }\n        pagemode = pagemode === \'mobile\' ? \'mobile\' : \'desktop\';\n        bodyClassList.push(pagemode);\n        if (C(\'hidesearch\') === \'1\' && pagemode !== \'mobile\') {\n      ...

# %%
search_soup = BeautifulSoup(search_page, 'lxml')
search_soup
# Out:
# <html><body><p>﻿<!DOCTYPE html>
#
# </p>
# <title>SF bay area cars &amp; trucks  - craigslist</title>
# <meta content="SF bay area cars &amp; trucks  - craigslist" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <link href="https://sfbay.craigslist.org/search/cta" rel="canonical"/>
# <link href="https://sfbay.craigslist.org/search/cta?format=rss" rel="alternate" title="RSS feed for craigslist | SF bay area cars &amp; trucks  - craigslist" type="application/rss+xml"/>
# <link href="https://sfbay.craigslist.org/search/cta?s=120" rel="next"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">
# <![endif]-->
# <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "1";
# var areaRegion = "CA";
# var catAbb = "cta";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = {"owner":"cto","dealer":"ctd","all":"cta"};
# var searchDistance = null;
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
# <section class="page-container" id="page-top">
# <div class="bglogo"></div>
# <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#         Android
#     </a>
# <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#         iOS
#     </a>
# </div>
# <header class="global-header wide">
# <a class="header-logo" href="/" name="logoLink">CL</a>
# <nav class="breadcrumbs-container">
# <form action="/search/cta" class="breadcrumbs-form" data-action="/search/###/cta" id="breadcrumbform" method="get">
# <ul class="breadcrumbs">
# <li class="crumb area">
# <span class="no-js">
# <a href="/">SF bay area</a>
# </span>
# <select class="js-only" id="areaAbb" name="areaAbb">
# <option value="sfbay">SF bay area</option>
# <option value="bakersfield">bakersfield</option>
# <option value="chico">chico</option>
# <option value="fresno">fresno</option>
# <option value="goldcountry">gold country</option>
# <option value="hanford">hanford</option>
# <option value="mendocino">mendocino co</option>
# <option value="merced">merced</option>
# <option value="modesto">modesto</option>
# <option value="monterey">monterey</option>
# <option value="redding">redding</option>
# <option value="reno">reno</option>
# <option value="sacramento">sacramento</option>
# <option value="slo">san luis obispo</option>
# <option value="santamaria">santa maria</option>
# <option value="stockton">stockton</option>
# <option value="susanville">susanville</option>
# <option value="visalia">visalia-tulare</option>
# <option value="yubasutter">yuba-sutter</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb subarea">
# <select id="subArea" name="subArea">
# <option selected="" value="">all SF bay area</option>
# <option value="eby">east bay</option>
# <option value="nby">north bay</option>
# <option value="pen">peninsula</option>
# <option value="sfc">san francisco</option>
# <option value="scz">santa cruz</option>
# <option value="sby">south bay</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb section">
# <select id="catAbb" name="catAbb">
# <option value="ccc">community</option>
# <option value="eee">events</option>
# <option selected="" value="sss">for sale</option>
# <option value="ggg">gigs</option>
# <option value="hhh">housing</option>
# <option value="jjj">jobs</option>
# <option value="rrr">resumes</option>
# <option value="bbb">services</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb category">
# <select class="js-only" id="subcatAbb">
# <option value="sss">all</option>
# <option value="ata">antiques</option>
# <option value="ppa">appliances</option>
# <option value="ara">arts+crafts</option>
# <option value="sna">atvs/utvs/snow</option>
# <option value="pta">auto parts</option>
# <option value="wta">auto wheels &amp; tires</option>
# <option value="ava">aviation</option>
# <option value="baa">baby+kids</option>
# <option value="bar">barter</option>
# <option value="haa">beauty+hlth</option>
# <option value="bip">bike parts</option>
# <option value="bia">bikes</option>
# <option value="bpa">boat parts</option>
# <option value="boo">boats</option>
# <option value="bka">books</option>
# <option value="bfa">business</option>
# <option selected="" value="cta">cars+trucks</option>
# <option value="ema">cds/dvd/vhs</option>
# <option value="moa">cell phones</option>
# <option value="cla">clothes+acc</option>
# <option value="cba">collectibles</option>
# <option value="syp">computer parts</option>
# <option value="sya">computers</option>
# <option value="ela">electronics</option>
# <option value="gra">farm+garden</option>
# <option value="zip">free stuff</option>
# <option value="fua">furniture</option>
# <option value="gms">garage sales</option>
# <option value="foa">general</option>
# <option value="hva">heavy equipment</option>
# <option value="hsa">household</option>
# <option value="jwa">jewelry</option>
# <option value="maa">materials</option>
# <option value="mpa">motorcycle parts</option>
# <option value="mca">motorcycles</option>
# <option value="msa">music instr</option>
# <option value="pha">photo+video</option>
# <option value="rva">RVs</option>
# <option value="sga">sporting</option>
# <option value="tia">tickets</option>
# <option value="tla">tools</option>
# <option value="taa">toys+games</option>
# <option value="tra">trailers</option>
# <option value="vga">video gaming</option>
# <option value="waa">wanted</option>
# </select><span class="no-js">cars+trucks</span>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb no-js">
# <input type="submit" value="go"/>
# </li>
# </ul>
# </form>
# </nav>
# <div class="userlinks">
# <ul class="user-actions">
# <li class="user post">
# <a href="https://post.craigslist.org/c/sfo">post</a>
# </li>
# <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>
# </ul>
# <ul class="user-favs-discards">
# <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
# </div>
# </li>
# <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="POST">
# <div class="to-banish-page">
# <input class="lastLink" name="lastLink" type="hidden" value="//sfbay.craigslist.org/search/cta"/>
# <input class="lastTitle" name="lastTitle" type="hidden" value=""/>
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count">0</span>
# <span class="discards-label"> hidden</span>
# </a>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </header>
# <header class="global-header narrow">
# <a class="header-logo" href="/">CL</a>
# <nav class="breadcrumbs-container">
# <ul class="breadcrumbs">
#
#
# SF bay area            &gt;
#
# cars &amp; trucks
#
# </ul>
# </nav>
# <span class="linklike show-wide-header">...</span>
# </header>
# <form action="/search/cta" class="search-form" id="searchform">
# <div class="querybox">
# <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search cars &amp; trucks" type="text" value=""/>
# <button class="searchbtn" type="submit">
# <span aria-hidden="true" class="icon icon-search"></span>
# <span class="screen-reader-text">press to search craigslist</span>
# </button>
# <div class="savealert">
# <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fsfbay%2Ecraigslist%2Eorg%2Fsearch%2Fcta" title="save this search">save search</a>
# </div>
# </div>
# <div class="search-options-container">
# <h2 class="search-options-header linklike">
# <div aria-hidden="true" class="icon icon-toggle-gear"></div>
#         options<span class="options-close">close</span>
# </h2>
# <input id="excats" name="excats" type="hidden"/>
# <div class="search-options">
# <div class="searchgroup categories">
# <div class="cattitle">
# <a class="reset" href="/search/cta" title="clear all search parameters">cars &amp; trucks</a>
# </div>
# </div>
# <input name="userid" type="hidden" value=""/>
# <ul class="searchgroup buttongroup purveyor">
# <li class="button sel">
# <a data-val="all" href="/search/cta">all</a>
# </li><li class="button">
# <a data-val="owner" href="/search/cto"> owner</a>
# </li><li class="button">
# <a data-val="dealer" href="/search/ctd">dealer</a>
# </li>
# </ul>
# <div class="searchgroup">
# <ul>
# <li>
# <label class="srchType">
# <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#        </label>
# </li>
# <li>
# <label class="hasPic">
# <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#        </label>
# </li>
# <li>
# <label class="postedToday">
# <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#        </label>
# </li>
# <li>
# <label class="bundleDuplicates">
# <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#        </label>
# </li>
# <li>
# <label class="searchNearby">
# <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#        </label>
# </li>
# </ul>
# <ul class="js-only nearbyAreas">
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="63"/>
#                             bakersfield, CA <small>(bak)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="187"/>
#                             chico, CA <small>(chc)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="43"/>
#                             fresno / madera <small>(fre)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="373"/>
#                             gold country <small>(gld)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="709"/>
#                             hanford-corcoran <small>(hnf)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="189"/>
#                             humboldt county <small>(hmb)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="454"/>
#                             mendocino county <small>(mdo)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="285"/>
#                             merced, CA <small>(mer)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="96"/>
#                             modesto, CA <small>(mod)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="102"/>
#                             monterey bay <small>(mtb)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="188"/>
#                             redding, CA <small>(rdd)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="92"/>
#                             reno / tahoe <small>(rno)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="12"/>
#                             sacramento <small>(sac)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="191"/>
#                             san luis obispo <small>(slo)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="62"/>
#                             santa barbara <small>(sba)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="710"/>
#                             santa maria, CA <small>(smx)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="708"/>
#                             siskiyou county <small>(ssk)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="97"/>
#                             stockton, CA <small>(stk)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="707"/>
#                             susanville, CA <small>(ssn)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="208"/>
#                             ventura county <small>(oxr)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="346"/>
#                             visalia-tulare <small>(vis)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="456"/>
#                             yuba-sutter, CA <small>(ybs)</small>
# </label>
# </li>
# <li>
# <span class="nextNearbyZone linklike" data-zone="1">
#                             + show <span id="nearbyNumber">22</span> more...
#                         </span>
# </li>
# </ul>
# </div>
# <div class="searchgroup">
# <span class="searchfieldlabel">miles from zip</span>
# <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value=""/>
# <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
# <span class="icon icon-locate"></span>
# </div>
# <div class="searchgroup minmax price">
# <span class="searchfieldlabel">price</span>
# <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# <div class="searchgroup"><span class="searchfieldlabel">make and model</span>
# <input class="flatinput auto_make_model" data-autocomplete="makemodel" name="auto_make_model" placeholder="make / model" type="text" value=""/>
# </div><div class="searchgroup"> <div class="minmax auto_year">
# <span class="searchfieldlabel">model year</span>
# <input class="flatinput min" name="min_auto_year" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_auto_year" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# <div class="minmax auto_miles">
# <span class="searchfieldlabel">odometer</span>
# <input class="flatinput min" name="min_auto_miles" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_auto_miles" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# </div><div class="searchgroup"><label class="crypto_currency_ok">
# <input class="autosubmit" name="crypto_currency_ok" type="checkbox" value="1"/>
#     cryptocurrency ok
# </label><br/>
# <label class="delivery_available">
# <input class="autosubmit" name="delivery_available" type="checkbox" value="1"/>
#     delivery available
# </label><br/>
# </div><div class="searchgroup"><div class="search-attribute hide-list" data-attr="language">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> language of posting
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_1" name="language" type="checkbox" value="1"/>
#                     af
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_2" name="language" type="checkbox" value="2"/>
#                     ca
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_3" name="language" type="checkbox" value="3"/>
#                     da
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_4" name="language" type="checkbox" value="4"/>
#                     de
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_5" name="language" type="checkbox" value="5"/>
#                     en
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_6" name="language" type="checkbox" value="6"/>
#                     es
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_7" name="language" type="checkbox" value="7"/>
#                     fi
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_8" name="language" type="checkbox" value="8"/>
#                     fr
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_9" name="language" type="checkbox" value="9"/>
#                     it
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_10" name="language" type="checkbox" value="10"/>
#                     nl
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_11" name="language" type="checkbox" value="11"/>
#                     no
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_12" name="language" type="checkbox" value="12"/>
#                     pt
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_13" name="language" type="checkbox" value="13"/>
#                     sv
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_14" name="language" type="checkbox" value="14"/>
#                     tl
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_15" name="language" type="checkbox" value="15"/>
#                     tr
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_16" name="language" type="checkbox" value="16"/>
#                     zh
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_17" name="language" type="checkbox" value="17"/>
#                     ar
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_18" name="language" type="checkbox" value="18"/>
#                     ja
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_19" name="language" type="checkbox" value="19"/>
#                     ko
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_20" name="language" type="checkbox" value="20"/>
#                     ru
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="language_21" name="language" type="checkbox" value="21"/>
#                     vi
#                 </label>
# </li>
# <li class="selectall js-only">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="condition">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> condition
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="condition_10" name="condition" type="checkbox" value="10"/>
#                     new
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="condition_20" name="condition" type="checkbox" value="20"/>
#                     like new
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="condition_30" name="condition" type="checkbox" value="30"/>
#                     excellent
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="condition_40" name="condition" type="checkbox" value="40"/>
#                     good
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="condition_50" name="condition" type="checkbox" value="50"/>
#                     fair
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="condition_60" name="condition" type="checkbox" value="60"/>
#                     salvage
#                 </label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_cylinders">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> cylinders
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_1" name="auto_cylinders" type="checkbox" value="1"/>
#                     3 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_2" name="auto_cylinders" type="checkbox" value="2"/>
#                     4 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_3" name="auto_cylinders" type="checkbox" value="3"/>
#                     5 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_4" name="auto_cylinders" type="checkbox" value="4"/>
#                     6 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_5" name="auto_cylinders" type="checkbox" value="5"/>
#                     8 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_6" name="auto_cylinders" type="checkbox" value="6"/>
#                     10 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_7" name="auto_cylinders" type="checkbox" value="7"/>
#                     12 cylinders
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_cylinders_8" name="auto_cylinders" type="checkbox" value="8"/>
#                     other
#                 </label>
# </li>
# <li class="selectall js-only">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_drivetrain">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> drive
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_drivetrain_1" name="auto_drivetrain" type="checkbox" value="1"/>
#                     fwd
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_drivetrain_2" name="auto_drivetrain" type="checkbox" value="2"/>
#                     rwd
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_drivetrain_3" name="auto_drivetrain" type="checkbox" value="3"/>
#                     4wd
#                 </label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_fuel_type">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> fuel
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_fuel_type_1" name="auto_fuel_type" type="checkbox" value="1"/>
#                     gas
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_fuel_type_2" name="auto_fuel_type" type="checkbox" value="2"/>
#                     diesel
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_fuel_type_3" name="auto_fuel_type" type="checkbox" value="3"/>
#                     hybrid
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_fuel_type_4" name="auto_fuel_type" type="checkbox" value="4"/>
#                     electric
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_fuel_type_6" name="auto_fuel_type" type="checkbox" value="6"/>
#                     other
#                 </label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_paint">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> paint color
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_1" name="auto_paint" type="checkbox" value="1"/>
#                     black
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_2" name="auto_paint" type="checkbox" value="2"/>
#                     blue
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_20" name="auto_paint" type="checkbox" value="20"/>
#                     brown
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_3" name="auto_paint" type="checkbox" value="3"/>
#                     green
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_4" name="auto_paint" type="checkbox" value="4"/>
#                     grey
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_5" name="auto_paint" type="checkbox" value="5"/>
#                     orange
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_6" name="auto_paint" type="checkbox" value="6"/>
#                     purple
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_7" name="auto_paint" type="checkbox" value="7"/>
#                     red
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_8" name="auto_paint" type="checkbox" value="8"/>
#                     silver
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_9" name="auto_paint" type="checkbox" value="9"/>
#                     white
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_10" name="auto_paint" type="checkbox" value="10"/>
#                     yellow
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_paint_11" name="auto_paint" type="checkbox" value="11"/>
#                     custom
#                 </label>
# </li>
# <li class="selectall js-only">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_size">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> size
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_size_1" name="auto_size" type="checkbox" value="1"/>
#                     compact
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_size_2" name="auto_size" type="checkbox" value="2"/>
#                     full-size
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_size_3" name="auto_size" type="checkbox" value="3"/>
#                     mid-size
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_size_4" name="auto_size" type="checkbox" value="4"/>
#                     sub-compact
#                 </label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_title_status">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> title status
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_title_status_1" name="auto_title_status" type="checkbox" value="1"/>
#                     clean
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_title_status_2" name="auto_title_status" type="checkbox" value="2"/>
#                     salvage
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_title_status_3" name="auto_title_status" type="checkbox" value="3"/>
#                     rebuilt
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_title_status_4" name="auto_title_status" type="checkbox" value="4"/>
#                     parts only
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_title_status_5" name="auto_title_status" type="checkbox" value="5"/>
#                     lien
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_title_status_6" name="auto_title_status" type="checkbox" value="6"/>
#                     missing
#                 </label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_transmission">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> transmission
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_transmission_1" name="auto_transmission" type="checkbox" value="1"/>
#                     manual
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_transmission_2" name="auto_transmission" type="checkbox" value="2"/>
#                     automatic
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_transmission_3" name="auto_transmission" type="checkbox" value="3"/>
#                     other
#                 </label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="auto_bodytype">
# <div class="title linklike">
# <span class="plus">▸</span><span class="minus">▾</span> type
#     </div>
# <ul class="list">
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_1" name="auto_bodytype" type="checkbox" value="1"/>
#                     bus
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_2" name="auto_bodytype" type="checkbox" value="2"/>
#                     convertible
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_3" name="auto_bodytype" type="checkbox" value="3"/>
#                     coupe
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_4" name="auto_bodytype" type="checkbox" value="4"/>
#                     hatchback
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_5" name="auto_bodytype" type="checkbox" value="5"/>
#                     mini-van
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_6" name="auto_bodytype" type="checkbox" value="6"/>
#                     offroad
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_7" name="auto_bodytype" type="checkbox" value="7"/>
#                     pickup
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_8" name="auto_bodytype" type="checkbox" value="8"/>
#                     sedan
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_9" name="auto_bodytype" type="checkbox" value="9"/>
#                     truck
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_10" name="auto_bodytype" type="checkbox" value="10"/>
#                     SUV
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_11" name="auto_bodytype" type="checkbox" value="11"/>
#                     wagon
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_12" name="auto_bodytype" type="checkbox" value="12"/>
#                     van
#                 </label>
# </li>
# <li class="checkbox">
# <label>
# <input class="multi_checkbox" id="auto_bodytype_13" name="auto_bodytype" type="checkbox" value="13"/>
#                     other
#                 </label>
# </li>
# <li class="selectall js-only">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="searchgroup resetsearch">
# <a class="reset linklike" href="/search/cta" title="clear all search parameters">reset</a>
# <button class="searchlink linklike" type="submit">update search</button>
# </div>
# <aside class="tsb">
# <ul>
# <li><a href="https://www.craigslist.org/about/safety">safety tips</a>
# </li><li><a href="https://www.craigslist.org/about/prohibited">prohibited items</a>
# </li><li><a href="https://www.craigslist.org/about/recalled_items">product recalls</a>
# </li><li><a href="https://www.craigslist.org/about/scams">avoiding scams</a>
# </li></ul>
# </aside>
# </div>
# </div>
# <div class="search-legend">
# <div class="search-view js-only">
# <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
# <ul class="dropdown-list">
# <li class="dropdown-item mode sel">
# <button data-selection="list" id="listview" title="show results in a list">
# <span class="view-list icon"></span>list
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
# <span class="view-thumb icon"></span>thumb
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
# <span class="view-gallery icon"></span>gallery
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="map" id="mapview" title="show results on a map">
# <span class="view-map icon"></span>map
#                     </button>
# <span class="toggle-arrow"></span>
# </li>
# </ul>
# </div>
# </div>
# <div class="search-sort">
# <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="date" role="toolbar">
# <ul class="dropdown-list">
# <li aria-selected="true" class="dropdown-item mode sel">
# <a data-selection="date" href="/search/cta?sort=date&amp;" title="show newest matches first">newest <span class="toggle-arrow"></span></a>
# </li>
# <li aria-selected="false" class="dropdown-item mode">
# <a data-selection="priceasc" href="/search/cta?sort=priceasc&amp;" title="sort by price, lowest to highest">price ↑ <span class="toggle-arrow"></span></a>
# </li>
# <li aria-selected="false" class="dropdown-item mode">
# <a data-selection="pricedsc" href="/search/cta?sort=pricedsc&amp;" title="sort by price, highest to lowest">price ↓ <span class="toggle-arrow"></span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="paginator buttongroup firstpage">
# <span class="resulttotal">
# <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/search/cta" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/search/cta" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">120</span>
# </span>
#             /
#             <span class="totalcount">3000</span>
# </span>
# <a class="button next" href="/search/cta?s=120" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <div class="content" id="sortable-results">
# <section class="favlistsection">
# <section class="favlistinfo">
# </section>
# <section class="banishlistinfo">
# </section>
# </section>
# <div class="open-map-view-button">
# <span>see in map view</span>
# </div>
# <div data-arealat="37.500000" data-arealon="-122.250000" id="mapcontainer">
# <div id="noresult-overlay"></div>
# <div id="noresult-text">
# <span class="message">No mappable items found</span>
# </div>
# <div class="loading" id="map">
# <div class="close-full-screen-map-mode-button">close fullscreen</div>
# <div class="close-map-view-button">close map</div>
# </div>
# </div>
# <ul class="rows">
# <li class="result-row" data-pid="7156661924">
# <a class="result-image gallery" data-ids="3:00f0f_6ETCoF9x6RV_05e03V,3:00o0o_4WTTDaMmfDk_05a03X,3:00x0x_1nszwFXncag_05c03X,3:00B0B_cn4vCmCJO2Q_05g03T,3:00k0k_1iZv8cB1rMH_05c03W,3:00l0l_6jaFBNtPHz2_05a03U,3:00H0H_bF5vDRZHBco_05e03V" href="https://sfbay.craigslist.org/sby/cto/d/san-jose-2003-toyota-camry-xle-4/7156661924.html">
# <span class="result-price">$3800</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2020-07-09 22:10" title="Thu 09 Jul 10:10:23 PM">Jul  9</time>
# <a class="result-title hdrlnk" data-id="7156661924" href="https://sfbay.craigslist.org/sby/cto/d/san-jose-2003-toyota-camry-xle-4/7156661924.html">*2003 Toyota Camry XLE , 4 cylender .Price to Sell</a>
# <span class="result-meta">
# <span class="result-price">$3800</span>
# <span class="result-hood"> (san jose north)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="7156661748">
# <a class="result-image gallery" data-ids="3:00V0V_lBqF7jnrn2A_0CI0t2,3:00Z0Z_iN82J9Pdacx_0CI0t2,3:00D0D_lVdsvAUW3xl_0CI0t2,3:00606_fF0WevPpn2K_0CI0t2,3:00P0P_8whSdRbSaE4_0CI0t2,3:00Z0Z_iN82J9Pdacx_0CI0t2" href="https://sfbay.craigslist.org/sby/cto/d/los-gatos-bmw-750-li-2011/7156661748.html">
# <span class="result-price">$8500</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2020-07-09 22:09" title="Thu 09 Jul 10:09:27 PM">Jul  9</time>
# <a class="result-title hdrlnk" data-id="7156661748" href="https://sfbay.craigslist.org/sby/cto/d/los-gatos-bmw-750-li-2011/7156661748.html">BMW 750 LI 2011</a>
# <span class="result-meta">
# <span class="result-price">$8500</span>
# <span class="result-hood"> (los gatos)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="7
#  'https://sfbay.craigslist.org/eby/cto/d/union-city-1996-honda-civic-hatchback/7156636493.html',
#  'https://sfbay.craigslist.org/pen/cto/d/palo-alto-freightliner-cascadia-for/7156636344.html',
#  'https://sfbay.craigslist.org/sby/cto/d/campbell-2006-bmw-330i/7156636170.html',
#  'https://sfbay.craigslist.org/eby/cto/d/rodeo-2007-isuzu-nqr-18-ft-high-cube/7156636139.html',
#  'https://sfbay.craigslist.org/sby/cto/d/sacramento-1976-chevy-silverado-k10-c10/7156636131.html',
#  'https://sfbay.craigslist.org/sby/cto/d/morgan-hill-2005-infiniti-g35-coupe/7156635961.html']

# %%
# Checking that I grabbed all 120 URLs listed on Craigslist's main search results page
print(len(result_urls))
# Out:
# 120

# %% [markdown]
# Now that I know how to scrape one of Craigslist's main search results page, how do I get all of the other search pages?
# Noticed that Craigslist URLs follow a pattern. They add `?s=120`, then `?s=240`, etc. to the base url in increments of 120 all the way up to `?s=2880`.

# %%
# Generating a list of Craigslist search result URLs to pull individual car post URLs from.
url_list = ['https://sfbay.craigslist.org/search/cta']
for i in range(120, 2881, 120):
    url_list.append(f'{base_url}?s={i}')
url_list
# Out:
# ['https://sfbay.craigslist.org/search/cta',
#  'https://sfbay.craigslist.org/search/cta?s=120',
#  'https://sfbay.craigslist.org/search/cta?s=240',
#  'https://sfbay.craigslist.org/search/cta?s=360',
#  'https://sfbay.craigslist.org/search/cta?s=480',
#  'https://sfbay.craigslist.org/search/cta?s=600',
#  'https://sfbay.craigslist.org/search/cta?s=720',
#  'https://sfbay.craigslist.org/search/cta?s=840',
#  'https://sfbay.craigslist.org/search/cta?s=960',
#  'https://sfbay.craigslist.org/search/cta?s=1080',
#  'https://sfbay.craigslist.org/search/cta?s=1200',
#  'https://sfbay.craigslist.org/search/cta?s=1320',
#  'https://sfbay.craigslist.org/search/cta?s=1440',
#  'https://sfbay.craigslist.org/search/cta?s=1560',
#  'https://sfbay.craigslist.org/search/cta?s=1680',
#  'https://sfbay.craigslist.org/search/cta?s=1800',
#  'https://sfbay.craigslist.org/search/cta?s=1920',
#  'https://sfbay.craigslist.org/search/cta?s=2040',
#  'https://sfbay.craigslist.org/search/cta?s=2160',
#  'https://sfbay.craigslist.org/search/cta?s=2280',
#  'https://sfbay.craigslist.org/search/cta?s=2400',
#  'https://sfbay.craigslist.org/search/cta?s=2520',
#  'https://sfbay.craigslist.org/search/cta?s=2640',
#  'https://sfbay.craigslist.org/search/cta?s=2760',
#  'https://sfbay.craigslist.org/search/cta?s=2880']

# %% [markdown]
# #### 4. Building my DataFrame
#
# Here, I will build out a pipeline for web scraping

# %%
def get_year_make_model(car_soup):
    '''
    This function parses through the first group of attributes in the HTML and returns car year, make, and model

    Parameters:
        car_soup: BeautifulSoup HTML object
    Returns:
        car_year: year the car was made
        car_make: make of the car (e.g. Honda)
        car_model: model of the car (e.g. Accord)
    '''    
    
    if car_soup.find('p', class_='attrgroup'): # only assign year, make, and model if the attributes exist
        year_make_model = car_soup.find('p', class_='attrgroup')
    
        if len(year_make_model.text.strip().split()) > 2:
            car_year = year_make_model.text.strip().split()[0]
            car_make = year_make_model.text.strip().split()[1]
            car_model = ' '.join(year_make_model.text.strip().split()[2:])
        else:
            car_year = None
            car_make = None
            car_model = None
    else:
        car_year = None
        car_make = None
        car_model = None
    
    return car_year, car_make, car_model

# %%
def get_car_attributes(car_soup, car_dict):
    '''
    This function parses through the second group of attributes in the HTML and returns a dictionary with attribute names and values added
    Parameters:
        car_soup: BeautifulSoup HTML object
        car_dict: main dictionary to add car attributes
    Returns:
        car_dict: dictionary with attribute names and values added
    '''
    
    # if the second attribute group HTML tag exists, go to it
    if car_soup.find('p', class_='attrgroup') and car_soup.find('p', class_='attrgroup').find_next_sibling('p'):
        year_make_model = car_soup.find('p', class_='attrgroup')
        car_attributes = year_make_model.find_next_sibling('p')
    
        # grab attributes from the second attribute group
        for attr in car_attributes.find_all('span'):
            # attributes should look like "condition: excellent" rather than "cryptocurrency ok!" 
            if ':' in attr.text:
                attribute_name = attr.text.split(':')[0].strip()
                attribute_value = attr.text.split(':')[1].strip()
                car_dict[attribute_name] = attribute_value
    
    return car_dict

# %%
def get_title(car_soup):
    '''
    This function parses through the post title HTML id and returns the post title
    Parameters:
        car_soup: BeautifulSoup HTML object
    Returns:
        (the post title as text or None if the title can't be found)
    '''
    
    if car_soup.find('span', id='titletextonly'):
        return car_soup.find('span', id='titletextonly').text
    else:
        return None

# %%
def get_price(car_soup):
    '''
    This function parses through the price HTML class and returns the price
    Parameters:
        car_soup: BeautifulSoup HTML object
    Returns:
        (the price as text or None if the price can't be found)
    '''    
    
    if car_soup.find('span', class_='price'):
        return car_soup.find('span', class_='price').text
    else:
        return None

# %%
def get_location(car_soup):
    '''
    This function parses through the HTML and returns the post location
    Parameters:
        car_soup: BeautifulSoup HTML object
    Returns:
        (the post location as text or None if the location can't be found)
    '''    

    if car_soup.find('small'):
        # return "san mateo" instead of "(san mateo)"
        return car_soup.find('small').text.strip().replace('(','').replace(')','')
    else:
        return None

# %%
def get_posting_date(car_soup):
    '''
    This function parses through the time HTML tag and returns the posting time
    Parameters:
        car_soup: BeautifulSoup HTML object
    Returns:
        (the post time as text or None if the posting time can't be found)
    '''
    
    if car_soup.find('time', class_='date timeago'):
        return car_soup.find('time', class_='date timeago').text.strip()
    else:
        return None

# %%
def soupify_url(craigslist_url):
    '''
    This function sends a request to a Craigslist URL and tries to return the HTML
    as a BeautifulSoup HTML object.
    Parameters:
        craigslist_url: the url of the Craigslist car posting
    Returns:
        (the Craigslist car post BeautifulSoup HTML object)
    '''    
    
    try:
        response = requests.get(craigslist_url)
        car_page = response.text
        return BeautifulSoup(car_page, 'lxml')
    # if the URL doesn't work, print out the URL and return None
    except:
        print(craigslist_url + " is not okay")
        return None

# %%
def get_car_info(craigslist_url):
    '''
    This is the main function that puts everything together. It scrapes
    the Craigslist car url for attributes and returns a dictionary with all the scraped attributes.
    Parameters:
        craigslist_url: the url of the Craigslist car posting
    Returns:
        car_dict: a dictionary with all scraped attributes
    '''    
    
    car_soup = soupify_url(craigslist_url)
    
    if car_soup == None:
        return None
    
    car_dict = {}
    
    get_car_attributes(car_soup, car_dict)
    
    car_year, car_make, car_model = get_year_make_model(car_soup)
    car_dict['year'] = car_year
    car_dict['make'] = car_make
    car_dict['model'] = car_model
    
    car_dict['post_title'] = get_title(car_soup)
    car_dict['price'] = get_price(car_soup)
    car_dict['location'] = get_location(car_soup)
    car_dict['posting_date'] = get_posting_date(car_soup)
    
    car_dict['url'] = craigslist_url
    
    return car_dict

# %%
# testing my main function
sample_test_1 = get_car_info('https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html')
# Note: this posting was deleted by the author

test_dict_1 = []
test_dict_1.append(sample_test_1)
# Out:
# https://sfbay.craigslist.org/sfc/cto/d/san-francisco-2007-toyota-camry-hybrid/7156527385.html is not okay

# %% [markdown]
# Now, I want to test my function on a Craigslist result search page

# %%
page_url = "https://sfbay.craigslist.org/search/cta"
search_page = requests.get(page_url).text
search_soup = BeautifulSoup(search_page, 'lxml')

# %%
# for one page of results, grab all the individual post URLs
all_results = search_soup.find_all('p', class_='result-info')
result_urls = []

for info in all_results:
    result_urls.append(info.find('a')['href'])
    
result_urls

# %%
# generate main craigslist search URLs
def generate_craigslist_urls():
    '''
    Generate a list of all Craigslist car posting search URLs
    Returns:
        search_craigslist_urls: a list of all craigslist search urls from ?s=120 to ?s=2880
    ''' 
    
    search_craigslist_urls = ['https://sfbay.craigslist.org/search/cta']
    base_url = "https://sfbay.craigslist.org/search/cta"

    for i in range(120, 2881, 120):
        search_craigslist_urls.append(f'{base_url}?s={i}')
    return search_craigslist_urls

# %%
# doing more testing
result_urls = []
for link in search_craigslist_urls:
    search_page = requests.get(link).text
    search_soup = BeautifulSoup(search_page, 'lxml')
    
    all_results = search_soup.find_all('p', class_='result-info')
    
    for result in all_results:
        result_urls.append(result.find('a')['href'])
        
    time.sleep(random.randint(1,2))
        
print(len(result_urls))
# Out:
# 480

# %% [markdown]
# #### 5. Saving the Data
#
# My goal is to scrape Craigslist on July 10, 11, and 12, save the URLs to a CSV, use the URLs to generate dictionaries for each car posting, turn the dictionaries into a DataFrame, and then save the DataFrame as a pickle.

# %%
# Generate main Craigslist search result URLs
search_craigslist_urls = generate_craigslist_urls()
search_craigslist_urls

# %%
# This was performed on July 10, 2020. Grab all the individual Craigslist post URLs from the main search pages.
result_urls = []
for link in search_craigslist_urls:
    search_page = requests.get(link).text
    search_soup = BeautifulSoup(search_page, 'lxml')
    
    all_results = search_soup.find_all('p', class_='result-info')
    
    for result in all_results:
        result_urls.append(result.find('a')['href'])
        
    time.sleep(random.randint(1,2))
result_urls
# Out:
# ['https://sfbay.craigslist.org/eby/cto/d/concord-2013-chevy-tahoe-salvage-con/7156858229.html',
#  'https://sfbay.craigslist.org/nby/ctd/d/2017-volvo-xc90-design/7156857632.html',
#  'https://sfbay.craigslist.org/scz/ctd/d/monterey-2013-audi-q5-quattro-4dr-20t/7156857622.html',
#  'https://sfbay.craigslist.org/sfc/ctd/d/san-jose-2013-hyundai-veloster-z/7156857576.html',
#  'https://sfbay.craigslist.org/sfc/ctd/d/san-jose-2012-mitsubishi-galant-z/7156857334.html',
#  'https://sfbay.craigslist.org/sby/ctd/d/watsonville-2019-gmc-yukon-4wd-4d-sport/7156857189.html',
#  'https://sfbay.craigslist.org/sfc/ctd/d/san-jose-2012-acura-tl-z-financing/7156857020.html',
#  'https://sfbay.craigslist.org/sfc/ctd/d/san-jose-2012-acura-tl-z-financing/7156856746.html',
#  'https://sfbay.craigslist.org/scz/ctd/d/watsonville-2017-jeep-cherokee-fwd-4d/7156856673.html',
#  'https://sfbay.craigslist.org/sfc/ctd/d/san-jose-
html',
#  'https://sfbay.craigslist.org/sby/cto/d/san-jose-2003-limousine-mint-condition/7156556883.html',
#  'https://sfbay.craigslist.org/sby/cto/d/san-jose-2014-dodge-ram-3500/7156556699.html',
#  'https://sfbay.craigslist.org/nby/cto/d/inverness-corvette-stingray/7156556700.html',
#  'https://sfbay.craigslist.org/eby/cto/d/brentwood-2008-audi-a6-line-bose-system/7156556165.html',
#  'https://sfbay.craigslist.org/eby/ctd/d/vacaville-fleet-special-last-2019-ram/7156556134.html',
#  ...]

# %%
# Turn the list of URLs into a DataFrame
result_urls_df = pd.DataFrame(result_urls)
result_urls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3000 non-null   object
# dtypes: object(1)
# memory usage: 23.6+ KB

# %%
# Save the July 10, 2020 URLs to a CSV
result_urls_df.to_csv('data/july_10_craigslist_urls.csv', index=False)

# %%
# Test opening the CSV
with open('data/july_10_craigslist_urls.csv', 'r') as file:
    # there is a 0 saved as the first value of the csv that I don't want
    july_10_urls = [url.strip() for url in file][1:]
july_10_urls

# %%
# Use my main function to generate car attribute dictionaries for each Craigslist post URL
july_10_info = []

for url in july_10_urls:
    july_10_info.append(get_car_info(url))
    time.sleep(1)
# Out:
# https://sfbay.craigslist.org/sby/ctd/d/redwood-city-2014-dodge-challenger-t/7156835400.html is not okay
# https://sfbay.craigslist.org/pen/cto/d/south-san-francisco-reduced-price-2014/7155810710.html is not okay

# %%
# Check the first five entries of the list
july_10_info[:5]

# %%
# Remove any values where the URL didn't work and the data is None rather than a dictionary
cleaned_july_10_info = [data for data in july_10_info if data != None]
cleaned_july_10_info

# %%
# Generate a DataFrame for the July 10, 2020 data
july_10_df = pd.DataFrame(cleaned_july_10_info)
july_10_df.head()
# Out:
#    condition    cylinders drive fuel odometer paint color title status  \
# 0       good  8 cylinders   rwd  gas   160000       black      salvage
# 1  excellent  4 cylinders   4wd  gas    36368       white        clean
# 2        NaN  4 cylinders   4wd  gas    59541       black        clean
# 3        NaN  4 cylinders   fwd  gas   102693       black        clean
# 4        NaN  4 cylinders   fwd  gas    64183       white        clean
#
#   transmission   type  year        make     model  \
# 0    automatic    SUV  2013       chevy  tahoe lt
# 1    automatic    SUV  2017       volvo      xc90
# 2        other    SUV  2013        Audi        Q5
# 3    automatic  other  2013     Hyundai  Veloster
# 4    automatic  sedan  2012  Mitsubishi    Galant
#
#                                     post_title   price  \
# 0  2013 Chevy Tahoe  salvage con 160000 millas  $10300
# 1                    ✭2017 Volvo XC90 R-Design  $34800
# 2   2013 Audi Q5 quattro 4dr 2.0T Premium Plus  $17900
# 3       2013 Hyundai Veloster - E-Z Financing!   $8499
# 4      2012 Mitsubishi Galant - E-Z Financing!   $6499
#
#                              location      posting_date  \
# 0  concord / pleasant hill / martinez  2020-07-10 09:14
# 1                          san rafael  2020-07-10 09:14
# 2                        2013 Audi Q5  2020-07-10 09:14
# 3                                None  2020-07-10 09:14
# 4                                None  2020-07-10 09:13
#
#                                                  url                VIN  \
# 0  https://sfbay.craigslist.org/eby/cto/d/concord...                NaN
# 1  https://sfbay.craigslist.org/nby/ctd/d/2017-vo...  YV4102KMXH1131603
# 2  https://sfbay.craigslist.org/scz/ctd/d/montere...  WA1LFAFP2DA057459
# 3  https://sfbay.craigslist.org/sfc/ctd/d/san-jos...  KMHTC6AE1DU158388
# 4  https://sfbay.craigslist.org/sfc/ctd/d/san-jos...  4A32B3FF9CE017464
#
#        size
# 0       NaN
# 1  mid-size
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Save the July 10 data as a pickle
with open('data/july_10.pickle', 'wb') as to_write:
    pickle.dump(july_10_df, to_write)

# %%
# make a function to get all the car posting URLs
def get_individual_car_urls(search_craigslist_urls):
    '''
    Obtain individual car posting URLs
    Parameters:
        search_craigslist_urls: the urls of the Craigslist main results page
    Returns:
        result_urls: a list of URLs corresponding to individual Craigslist car postings
    '''
    
    result_urls = []
    
    for link in search_craigslist_urls:
        search_page = requests.get(link).text
        search_soup = BeautifulSoup(search_page, 'lxml')
        
        all_results = search_soup.find_all('p', class_='result-info')
        
        for result in all_results:
            result_urls.append(result.find('a')['href'])
        
        time.sleep(random.randint(1,2))
    
    return result_urls

# %%
# Grab individual Craigslist car post URLs for July 11
july_11_result_urls = get_individual_car_urls(search_craigslist_urls)
july_11_result_urls

# %%
# Turn the URLs into CSV
july_11_result_urls_df = pd.DataFrame(july_11_result_urls)
july_11_result_urls_df.to_csv('data/july_11_craigslist_urls.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3000 non-null   object
# dtypes: object(1)
# memory usage: 23.6+ KB

# %%
# Remove URLs that I already collected attributes for
def remove_duplicate_urls(new_urls, old_urls):
    '''
    Go through a list of recently acquired urls and remove any duplicate urls that were in a previously
    collected list of urls.
    Parameters:
        new_urls: a list of Craigslist car post URLs that were recently collected
        old_urls: a list of Craigslist car post URLs that were collected previously
    Returns:
        new_urls_deduped: a list of Craigslist car post URLs recently collected with previously collecte urls
        removed
    '''
    
    new_urls_deduped = []
    
    for url in new_urls:
        if url not in old_urls:
            new_urls_deduped.append(url)
    
    return new_urls_deduped

# %%
# save the July 11 individual Craigslist car posting URLs
with open('data/july_11_craigslist_urls.csv', 'r') as file:
    # there is a 0 saved as the first value of the csv that I don't want
    july_11_urls = [url.strip() for url in file][1:]
july_11_urls[:5]
# Out:
# ['https://sfbay.craigslist.org/eby/ctd/d/livermore-2015-subaru-impreza-awd-sedan/7157444766.html',
#  'https://sfbay.craigslist.org/eby/cto/d/hayward-2005-honda-pilot-ex-4wd/7157444757.html',
#  'https://sfbay.craigslist.org/eby/ctd/d/fremont-2006-mercedes-benz-clk-class/7157444754.html',
#  'https://sfbay.craigslist.org/sfc/ctd/d/san-jose-2001-honda-civic-lx-all-great/7157444565.html',
#  'https://sfbay.craigslist.org/eby/ctd/d/fremont-2008-mercedes-benz-clk-class/7157444545.html']

# %%
# remove duplicate links scraped from July 11th that were already in my july 10th urls
july_11_urls_deduped = remove_duplicate_urls(july_11_urls, july_10_urls)
len(july_11_urls_deduped)
# Out:
# 2537

# %%
# Use my main function to generate car attribute dictionaries for each Craigslist post URL 
july_11_info = []

for url in july_11_urls_deduped:
    july_11_info.append(get_car_info(url))
    time.sleep(0.5)
# Out:
# https://sfbay.craigslist.org/eby/ctd/d/stockton-2012-mercedes-benz-ml350-ml/7156914606.html is not okay

# %%
# Remove any values where the URL didn't work or the data is None rather than a dictionary
cleaned_july_11_info = [data for data in july_11_info if data != None]
cleaned_july_11_info

# %%
# Generate a DataFrame for the July 11, 2020 data
july_11_df = pd.DataFrame(cleaned_july_11_info)
july_11_df.head()
# Out:
#                  VIN  condition    cylinders drive fuel odometer paint color  \
# 0  JF1GJAA63FH008498  excellent  4 cylinders   4wd  gas    99245        blue
# 1                NaN        NaN          NaN   4wd  gas   210000         NaN
# 2  WDBTK76GX6T068610  excellent          NaN   rwd  gas   141303      silver
# 3  2HGES16501H559491  excellent  4 cylinders   fwd  gas      148       white
# 4  WDBTJ56H38F256449  excellent          NaN   rwd  gas   133849      silver
#
#   title status transmission         type  year           make          model  \
# 0        clean    automatic        sedan  2015         Subaru  Impreza sedan
# 1        clean    automatic          NaN  None           None           None
# 2        clean    automatic  convertible  2006  Mercedes-Benz      CLK-Class
# 3      salvage    automatic        sedan  2001          honda       civic LX
# 4        clean    automatic        coupe  2008  Mercedes-Benz      CLK-Class
#
#                                           post_title     price  \
# 0  2015 Subaru Impreza AWD Sedan. Clean, Runs exc...     $8800
# 1                            2005 Honda Pilot EX 4WD     $4200
# 2  2006 Mercedes-Benz CLK-Class CLK 55 AMG Cabrio...  $9999.00
# 3  2001 Honda Civic LX All Great Tires Clean/Runs...     $2650
# 4  2008 Mercedes-Benz CLK-Class CLK 350 Coupe 2D ...  $6999.00
#
#                                             location      posting_date  \
# 0                    dublin / pleasanton / livermore  2020-07-11 09:05
# 1                            hayward / castro valley  2020-07-11 09:05
# 2  *2006* *Mercedes-Benz* *CLK-Class* *CLK* *55* ...  2020-07-11 09:05
# 3                                               None  2020-07-11 09:05
# 4  *2008* *Mercedes-Benz* *CLK-Class* *CLK* *350*...  2020-07-11 09:05
#
#                                                  url     size
# 0  https://sfbay.craigslist.org/eby/ctd/d/livermo...      NaN
# 1  https://sfbay.craigslist.org/eby/cto/d/hayward...      NaN
# 2  https://sfbay.craigslist.org/eby/ctd/d/fremont...      NaN
# 3  https://sfbay.craigslist.org/sfc/ctd/d/san-jos...  compact
# 4  https://sfbay.craigslist.org/eby/ctd/d/fremont...      NaN

# %%
# Save the July 11 data as a pickle
with open('data/july_11.pickle', 'wb') as to_write:
    pickle.dump(july_11_df, to_write)

# %%
# Grab individual Craigslist car post URLs for July 12
july_12_result_urls = get_individual_car_urls(search_craigslist_urls)
july_12_result_urls[:5]
# Out:
# ['https://sfbay.craigslist.org/nby/ctd/d/santa-rosa-imca-dirt-modified-harris/7158004149.html',
#  'https://sfbay.craigslist.org/sby/ctd/d/fremont-2019-subaru-forester-suv-acura/7158003421.html',
#  'https://sfbay.craigslist.org/nby/cto/d/rohnert-park-2003-ford-expedition-eddie/7158003322.html',
#  'https://sfbay.craigslist.org/sby/cto/d/palo-alto-2009-honda-fit-sport/7158002840.html',
#  'https://sfbay.craigslist.org/eby/cto/d/livermore-2008-dodge-ram-mega-can/7158002379.html']

# %%
# Turn the URLs into CSV
july_12_result_urls_df = pd.DataFrame(july_12_result_urls)
july_12_result_urls_df.to_csv('data/july_12_craigslist_urls.csv', index=False)

# %%
# save the July 12 individual Craigslist car posting URLs
with open('data/july_12_craigslist_urls.csv', 'r') as file:
    # there is a 0 saved as the first value of the csv that I don't want
    july_12_urls = [url.strip() for url in file][1:]
july_12_urls[:5]
# Out:
# ['https://sfbay.craigslist.org/nby/ctd/d/santa-rosa-imca-dirt-modified-harris/7158004149.html',
#  'https://sfbay.craigslist.org/sby/ctd/d/fremont-2019-subaru-forester-suv-acura/7158003421.html',
#  'https://sfbay.craigslist.org/nby/cto/d/rohnert-park-2003-ford-expedition-eddie/7158003322.html',
#  'https://sfbay.craigslist.org/sby/cto/d/palo-alto-2009-honda-fit-sport/7158002840.html',
#  'https://sfbay.craigslist.org/eby/cto/d/livermore-2008-dodge-ram-mega-can/7158002379.html']

# %%
# remove duplicate links scraped from july 12th that were already in my july 11th urls
july_12_urls_deduped = remove_duplicate_urls(july_12_urls, july_11_urls)
len(july_12_urls_deduped)
# Out:
# 1909

# %%
# Use my main function to generate car attribute dictionaries for each Craigslist post URL 
july_12_info = []

for url in july_12_urls_deduped:
    july_12_info.append(get_car_info(url))
    time.sleep(0.5)

# %%
# Remove any values where the URL didn't work and the data is None rather than a dictionary
cleaned_july_12_info = [data for data in july_12_info if data != None]
cleaned_july_12_info

# %%
# Generate a DataFrame for the July 12, 2020 data
july_12_df = pd.DataFrame(cleaned_july_12_info)
july_12_df.head()
# Out:
#     fuel title status transmission  year    make         model  \
# 0  other        clean        other  2017    dirt      modified
# 1    gas        clean    automatic  2019  Subaru      Forester
# 2    gas        clean    automatic  2003    ford    expedition
# 3    gas        clean       manual  2009   Honda     Fit Sport
# 4    gas        clean    automatic  2008   dodge  ram mega cab
#
#                                           post_title      price  \
# 0                  Imca Dirt Modified Harris Chassis      $9000
# 1  2019 Subaru Forester SUV ( Acura of Fremont : ...  $29458.00
# 2                   2003 Ford Expedition Eddie Bauer      $4200
# 3                               2009 Honda Fit Sport      $7300
# 4                            2008 Dodge Ram mega cab     $20000
#
#               location      posting_date  \
# 0           santa rosa  2020-07-12 09:25
# 1           google map  2020-07-12 09:24
# 2  rohnert pk / cotati  2020-07-12 09:24
# 3            Palo Alto  2020-07-12 09:23
# 4            Livermore  2020-07-12 09:22
#
#                                                  url                VIN  \
# 0  https://sfbay.craigslist.org/nby/ctd/d/santa-r...                NaN
# 1  https://sfbay.craigslist.org/sby/ctd/d/fremont...  JF2SKAEC1KH442013
# 2  https://sfbay.craigslist.org/nby/cto/d/rohnert...                NaN
# 3  https://sfbay.craigslist.org/sby/cto/d/palo-al...  JHMGE87419S063728
# 4  https://sfbay.craigslist.org/eby/cto/d/livermo...                NaN
#
#   odometer       type  condition    cylinders drive paint color       size
# 0      NaN        NaN        NaN          NaN   NaN         NaN        NaN
# 1    17691        SUV        NaN          NaN   NaN         NaN        NaN
# 2   152600        SUV       good  8 cylinders   4wd       black  full-size
# 3    61000  hatchback  excellent  4 cylinders   fwd         NaN        NaN
# 4   109600      truck       good  8 cylinders   4wd       white  full-size

# %%
# Save the July 12 data as a pickle
with open('data/july_12.pickle', 'wb') as to_write:
    pickle.dump(july_12_df, to_write)
